# %% [markdown]
# # Appendix A. 설치 명령어 모음
#
# 이 부록은 전체 LLM 교재 실습에서 사용한 주요 설치 명령어를 한곳에 모은 자료입니다.
#
# 각 장의 노트북에는 필요한 패키지 설치 셀이 포함되어 있지만, 전체 환경을 처음 준비할 때는 이 부록을 참고하면 편리합니다. VS Code와 Jupyter Notebook 환경에서 Python 패키지를 설치하고, Ollama, Gradio, LangChain, RAG, STT/TTS, 이미지 분류, 텍스트 시각화, AutoGen 실습에 필요한 패키지를 정리합니다.
#
# ## 이 부록에서 다루는 내용
#
# 1. Python 환경 확인
# 2. Jupyter Notebook 관련 설치
# 3. 기본 데이터 처리 패키지
# 4. Hugging Face와 Transformer 관련 설치
# 5. LangChain과 Ollama 관련 설치
# 6. Gradio UI 관련 설치
# 7. RAG와 벡터스토어 관련 설치
# 8. DB 접속 관련 설치
# 9. LangGraph와 LangSmith 설치
# 10. STT/TTS 설치
# 11. 이미지 분류와 멀티모달 설치
# 12. 텍스트 시각화 설치
# 13. AutoGen 설치
# 14. 전체 통합 설치 명령
#
# 필요한 패키지만 선택해서 설치해도 됩니다. 모든 실습을 진행하려면 마지막 통합 설치 명령을 참고할 수 있습니다.

# %% [markdown]
# ## A.1 Python 환경 확인
#
# VS Code에서 Jupyter Notebook을 사용할 때는 먼저 Python이 정상적으로 설치되어 있고, 현재 노트북 커널이 원하는 Python 환경을 사용하고 있는지 확인합니다.

# %%
# 교재 위치: Appendix A - Python 환경 확인
# 이 셀은 현재 노트북에서 사용하는 Python 실행 파일과 버전을 확인합니다.

# sys 모듈은 Python 실행 환경 정보를 확인할 때 사용합니다.
import sys

# sys.executable은 현재 노트북 커널이 사용하는 Python 실행 파일 경로를 보여줍니다.
print("Python 실행 파일:", sys.executable)

# sys.version은 현재 Python 버전 정보를 보여줍니다.
print("Python 버전:", sys.version)

# %% [markdown]
# ## A.2 pip 업그레이드
#
# 패키지 설치 전에 `pip`를 최신 버전으로 올리면 설치 오류를 줄일 수 있습니다.

# %%
# 교재 위치: Appendix A - pip 업그레이드
# 이 셀은 Python 패키지 설치 도구인 pip를 업그레이드합니다.

# 현재 Python 환경의 pip를 최신 버전으로 업그레이드합니다.
# !python -m pip install --upgrade pip

# setuptools와 wheel은 일부 패키지 빌드와 설치에 필요한 기본 도구입니다.
# !python -m pip install --upgrade setuptools wheel

# %% [markdown]
# ## A.3 Jupyter Notebook 관련 설치
#
# VS Code에서 `.ipynb` 파일을 실행하려면 Jupyter 관련 패키지가 필요합니다. VS Code 확장과 별개로 Python 환경에도 `jupyter`와 `ipykernel`이 설치되어 있어야 합니다.

# %%
# 교재 위치: Appendix A - Jupyter 관련 설치
# 이 셀은 Jupyter Notebook 실행에 필요한 패키지를 설치합니다.

# jupyter는 노트북 실행과 관련된 기본 패키지입니다.
# !pip install jupyter

# ipykernel은 현재 Python 환경을 Jupyter 커널로 사용할 수 있게 합니다.
# !pip install ipykernel

# notebook은 전통적인 Jupyter Notebook 실행 환경을 제공합니다.
# !pip install notebook

# %% [markdown]
# ## A.4 기본 데이터 처리 패키지
#
# LLM 실습에서는 텍스트, 표, JSON, 그래프, 파일 경로를 자주 다룹니다. 다음 패키지는 여러 장에서 반복적으로 사용됩니다.

# %%
# 교재 위치: Appendix A - 기본 데이터 처리 패키지
# 이 셀은 데이터 처리와 시각화에 자주 사용하는 기본 패키지를 설치합니다.

# pandas는 표 형태의 데이터를 처리할 때 사용합니다.
# !pip install pandas

# numpy는 수치 계산과 배열 처리를 위해 사용합니다.
# !pip install numpy

# matplotlib은 그래프와 이미지 시각화를 위해 사용합니다.
# !pip install matplotlib

# requests는 웹 요청을 보낼 때 사용합니다.
# !pip install requests

# python-dotenv는 .env 파일의 환경 변수를 불러올 때 사용합니다.
# !pip install python-dotenv

# %% [markdown]
# ## A.5 Hugging Face와 Transformer 관련 설치
#
# Hugging Face Pipeline, Transformer 모델, 이미지 분류 모델을 사용하려면 다음 패키지가 필요합니다.

# %%
# 교재 위치: Appendix A - Hugging Face 관련 설치
# 이 셀은 Hugging Face와 Transformer 모델 사용에 필요한 패키지를 설치합니다.

# transformers는 Hugging Face 모델과 pipeline 기능을 사용하기 위한 핵심 라이브러리입니다.
# !pip install transformers

# torch는 PyTorch 기반 모델 실행을 위해 사용합니다.
# !pip install torch

# accelerate는 모델 실행과 디바이스 배치를 도와주는 라이브러리입니다.
# !pip install accelerate

# sentencepiece는 일부 토크나이저 모델에서 필요합니다.
# !pip install sentencepiece

# pillow는 이미지 파일을 열고 처리할 때 사용합니다.
# !pip install pillow

# %% [markdown]
# ## A.6 LangChain과 Ollama 관련 설치
#
# LangChain은 프롬프트, 모델, 파서, 체인, retriever를 연결하는 데 사용합니다. Ollama는 로컬 LLM을 실행하는 데 사용합니다.
#
# Ollama 프로그램 자체는 Python 패키지가 아니라 별도 설치 프로그램으로 설치해야 합니다. Python에서는 `langchain-ollama`를 설치해 Ollama 모델을 호출합니다.

# %%
# 교재 위치: Appendix A - LangChain과 Ollama 관련 설치
# 이 셀은 LangChain과 Ollama 연동에 필요한 Python 패키지를 설치합니다.

# langchain은 LLM 앱 구성에 사용하는 기본 프레임워크입니다.
# !pip install langchain

# langchain-core는 LangChain의 핵심 인터페이스를 제공합니다.
# !pip install langchain-core

# langchain-community는 다양한 로더, 벡터스토어, 유틸리티 통합을 제공합니다.
# !pip install langchain-community

# langchain-ollama는 Ollama 로컬 모델을 LangChain에서 호출할 때 사용합니다.
# !pip install langchain-ollama

# tiktoken은 토큰 계산과 일부 텍스트 처리에서 사용할 수 있습니다.
# !pip install tiktoken

# %% [markdown]
# ## A.7 Gradio UI 관련 설치
#
# Gradio는 LLM 챗봇, RAG 챗봇, DB 챗봇, 음성 챗봇, 이미지 분류 UI를 빠르게 만들 때 사용합니다.

# %%
# 교재 위치: Appendix A - Gradio 설치
# 이 셀은 웹 UI 실습에 필요한 Gradio를 설치합니다.

# gradio는 Python 함수로 웹 기반 입력과 출력 화면을 만들 수 있게 합니다.
# !pip install gradio

# %% [markdown]
# ## A.8 RAG와 벡터스토어 관련 설치
#
# RAG 실습에서는 문서 로더, 텍스트 분할기, 임베딩, 벡터스토어가 필요합니다. FAISS와 Chroma는 대표적인 벡터스토어 실습 도구입니다.

# %%
# 교재 위치: Appendix A - RAG와 벡터스토어 설치
# 이 셀은 RAG 실습에 필요한 패키지를 설치합니다.

# faiss-cpu는 FAISS 벡터 검색을 CPU 환경에서 사용할 때 설치합니다.
# !pip install faiss-cpu

# chromadb는 Chroma 벡터 데이터베이스를 사용할 때 설치합니다.
# !pip install chromadb

# pypdf는 PDF 파일에서 텍스트를 읽을 때 사용합니다.
# !pip install pypdf

# beautifulsoup4는 HTML 문서를 파싱할 때 사용합니다.
# !pip install beautifulsoup4

# lxml은 HTML과 XML 파싱 성능을 높이는 데 사용할 수 있습니다.
# !pip install lxml

# sentence-transformers는 문장 임베딩 모델을 사용할 때 필요합니다.
# !pip install sentence-transformers

# %% [markdown]
# ## A.9 DB 접속 관련 설치
#
# DB 접속 LLM 챗봇에서는 SQLAlchemy와 DB 드라이버가 필요합니다. 사용하는 DB 종류에 따라 드라이버가 달라집니다.

# %%
# 교재 위치: Appendix A - DB 접속 관련 설치
# 이 셀은 DB 연결과 SQL 실행에 필요한 패키지를 설치합니다.

# sqlalchemy는 Python에서 DB 연결과 SQL 실행을 표준화해서 다룰 때 사용합니다.
# !pip install sqlalchemy

# pymysql은 MySQL 또는 MariaDB에 접속할 때 사용할 수 있는 드라이버입니다.
# !pip install pymysql

# mysql-connector-python은 MySQL 접속에 사용할 수 있는 또 다른 공식 드라이버입니다.
# !pip install mysql-connector-python

# psycopg2-binary는 PostgreSQL 접속에 사용할 수 있는 드라이버입니다.
# !pip install psycopg2-binary

# %% [markdown]
# ## A.10 LangGraph와 LangSmith 설치
#
# LangGraph는 LLM 실행 흐름을 그래프로 구성할 때 사용하고, LangSmith는 실행 추적과 평가에 사용합니다.

# %%
# 교재 위치: Appendix A - LangGraph와 LangSmith 설치
# 이 셀은 LangGraph와 LangSmith 실습에 필요한 패키지를 설치합니다.

# langgraph는 상태 기반 그래프 실행을 제공하는 라이브러리입니다.
# !pip install langgraph

# langsmith는 LangChain 실행 추적, 데이터셋, 평가 기능을 제공합니다.
# !pip install langsmith

# %% [markdown]
# ## A.11 STT와 TTS 관련 설치
#
# STT는 음성을 텍스트로 변환하고, TTS는 텍스트를 음성으로 변환합니다. Whisper와 gTTS 실습에 필요한 패키지는 다음과 같습니다.
#
# Whisper를 사용할 때는 `ffmpeg`가 별도로 필요할 수 있습니다. Windows에서는 ffmpeg 설치 후 PATH 등록이 필요할 수 있습니다.

# %%
# 교재 위치: Appendix A - STT와 TTS 설치
# 이 셀은 음성 인식과 음성 합성 실습에 필요한 패키지를 설치합니다.

# openai-whisper는 Whisper 기반 STT 모델을 로컬에서 사용할 때 설치합니다.
# !pip install openai-whisper

# gTTS는 Google Text-to-Speech를 사용해 텍스트를 mp3 음성으로 변환합니다.
# !pip install gTTS

# pydub은 오디오 파일 변환과 간단한 오디오 처리를 위해 사용합니다.
# !pip install pydub

# soundfile은 오디오 파일을 읽고 쓸 때 사용할 수 있습니다.
# !pip install soundfile

# %% [markdown]
# ## A.12 이미지 분류와 멀티모달 관련 설치
#
# 이미지 분류 실습은 Hugging Face, PyTorch, Pillow, Gradio를 중심으로 진행합니다. 일부 패키지는 앞의 설치 명령과 중복됩니다.

# %%
# 교재 위치: Appendix A - 이미지 분류와 멀티모달 설치
# 이 셀은 이미지 입력과 이미지 분류 실습에 필요한 패키지를 설치합니다.

# transformers는 이미지 분류 pipeline을 사용할 때 필요합니다.
# !pip install transformers

# torch는 이미지 분류 모델의 실행 백엔드로 사용됩니다.
# !pip install torch

# pillow는 이미지 파일을 열고 처리하는 데 사용됩니다.
# !pip install pillow

# gradio는 이미지 업로드 UI를 만들 때 사용됩니다.
# !pip install gradio

# %% [markdown]
# ## A.13 텍스트 시각화 관련 설치
#
# 워드클라우드와 텍스트 시각화 실습에서는 WordCloud, matplotlib, KoNLPy를 사용합니다. KoNLPy는 Java 환경 설정이 필요할 수 있습니다.

# %%
# 교재 위치: Appendix A - 텍스트 시각화 설치
# 이 셀은 워드클라우드와 한국어 텍스트 분석 실습에 필요한 패키지를 설치합니다.

# wordcloud는 단어 빈도를 바탕으로 워드클라우드 이미지를 생성합니다.
# !pip install wordcloud

# matplotlib은 그래프와 이미지를 화면에 표시합니다.
# !pip install matplotlib

# konlpy는 한국어 형태소 분석을 위해 사용할 수 있습니다.
# !pip install konlpy

# JPype1은 KoNLPy가 Java 기반 형태소 분석기를 사용할 때 필요할 수 있습니다.
# !pip install JPype1

# %% [markdown]
# ## A.14 AutoGen 설치
#
# 다중 에이전트 실습에서는 AutoGen 개념을 다룹니다. 실제 사용 시 모델 설정과 API 키 또는 로컬 모델 연동 설정이 필요합니다.

# %%
# 교재 위치: Appendix A - AutoGen 설치
# 이 셀은 AutoGen 기반 다중 에이전트 실습에 필요한 패키지를 설치합니다.

# pyautogen은 AutoGen 에이전트 구성을 위한 패키지입니다.
# !pip install pyautogen

# %% [markdown]
# ## A.15 전체 통합 설치 명령
#
# 아래 명령은 교재 전체 실습에 필요한 주요 패키지를 한 번에 설치하는 예시입니다. 환경에 따라 설치 시간이 오래 걸릴 수 있고, 일부 패키지는 운영체제나 Python 버전에 따라 추가 설정이 필요할 수 있습니다.
#
# 처음부터 전부 설치하지 않고, 각 장을 진행하면서 필요한 패키지만 설치해도 됩니다.

# %%
# 교재 위치: Appendix A - 전체 통합 설치 명령
# 이 셀은 전체 교재 실습에 필요한 주요 패키지를 한 번에 설치합니다.

# pip, setuptools, wheel을 먼저 최신화합니다.
# !python -m pip install --upgrade pip setuptools wheel

# Jupyter, 데이터 처리, 시각화, 환경 변수 관리 패키지를 설치합니다.
# !pip install jupyter ipykernel notebook pandas numpy matplotlib requests python-dotenv

# Hugging Face, PyTorch, 이미지 처리 관련 패키지를 설치합니다.
# !pip install transformers torch accelerate sentencepiece pillow

# LangChain, Ollama 연동, 추적과 그래프 실행 관련 패키지를 설치합니다.
# !pip install langchain langchain-core langchain-community langchain-ollama langgraph langsmith tiktoken

# Gradio UI 패키지를 설치합니다.
# !pip install gradio

# RAG와 벡터스토어 관련 패키지를 설치합니다.
# !pip install faiss-cpu chromadb pypdf beautifulsoup4 lxml sentence-transformers

# DB 접속 관련 패키지를 설치합니다.
# !pip install sqlalchemy pymysql mysql-connector-python psycopg2-binary

# 음성 처리 관련 패키지를 설치합니다.
# !pip install openai-whisper gTTS pydub soundfile

# 텍스트 시각화와 한국어 분석 관련 패키지를 설치합니다.
# !pip install wordcloud konlpy JPype1

# AutoGen 다중 에이전트 실습 패키지를 설치합니다.
# !pip install pyautogen

# %% [markdown]
# ## A.16 Ollama 설치와 모델 준비
#
# Ollama는 Python 패키지가 아니라 로컬 LLM 실행 프로그램입니다. 별도로 설치한 뒤 터미널에서 모델을 내려받아야 합니다.
#
# 대표 명령은 다음과 같습니다.
#
# ```powershell
# ollama pull llama3.1
# ollama run llama3.1
# ```
#
# 노트북에서 `ChatOllama(model="llama3.1")`을 사용하려면 Ollama가 실행 중이고, 해당 모델이 설치되어 있어야 합니다.

# %% [markdown]
# ## A.17 환경 변수 예시
#
# API 키와 추적 설정은 코드에 직접 적기보다 `.env` 파일이나 운영체제 환경 변수로 관리하는 것이 좋습니다.
#
# 예시 `.env` 파일은 다음과 같습니다.
#
# ```text
# LANGCHAIN_TRACING_V2=true
# LANGCHAIN_ENDPOINT=https://api.smith.langchain.com
# LANGCHAIN_API_KEY=여기에_LangSmith_API_KEY
# LANGCHAIN_PROJECT=llm-basic-practice
# OPENAI_API_KEY=여기에_OpenAI_API_KEY
# ```
#
# 공유하거나 제출하는 노트북에는 실제 API 키가 남아 있지 않도록 주의해야 합니다.

# %% [markdown]
# ## A.18 정리
#
# 이 부록에서는 전체 LLM 교재 실습에 필요한 설치 명령어를 정리했습니다.
#
# 핵심 정리는 다음과 같습니다.
#
# - VS Code와 Jupyter Notebook 실습에는 `jupyter`, `ipykernel`이 필요합니다.
# - Hugging Face 실습에는 `transformers`, `torch`가 필요합니다.
# - LangChain과 Ollama 연동에는 `langchain`, `langchain-ollama`가 필요합니다.
# - RAG 실습에는 `faiss-cpu`, `chromadb`, `pypdf`, `sentence-transformers`가 필요합니다.
# - DB 챗봇 실습에는 `sqlalchemy`와 DB별 드라이버가 필요합니다.
# - LangGraph와 LangSmith는 고도화와 추적에 사용합니다.
# - STT/TTS, 이미지 분류, 워드클라우드, AutoGen은 응용 실습에 맞춰 설치합니다.
#
# 다음 부록에서는 주요 오류와 해결 방법을 정리합니다.
