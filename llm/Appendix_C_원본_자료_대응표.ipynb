# %% [markdown]
# # Appendix C. 원본 자료 대응표
#
# 이 부록은 새로 제작한 LLM 교재가 원본 자료인 `05.LLM 기본_20260701.pdf`, `LLM/llm.ipynb`, `LLM/llm2.ipynb`의 어느 내용을 반영했는지 정리한 대응표입니다.
#
# 사용 목적은 다음과 같습니다.
#
# - 원본 PDF의 주요 개념이 새 교재 어디에 반영되었는지 확인합니다.
# - `llm.ipynb`의 실습 코드가 새 교재 어느 장에 확장되었는지 확인합니다.
# - `llm2.ipynb`의 DB 챗봇, 추가 응용 실습이 새 교재 어디에 들어갔는지 확인합니다.
# - 누락 없이 학습 흐름을 따라갈 수 있도록 전체 구조를 점검합니다.
#
# 이 부록은 실행 중심 노트북이라기보다, 전체 교재의 출처와 반영 위치를 확인하는 참조 문서입니다.

# %% [markdown]
# ## C.1 원본 자료 목록
#
# | 원본 자료 | 위치 | 역할 |
# |---|---|---|
# | PDF 교재 | `Book/05.LLM 기본_20260701.pdf` | LLM 기본 개념, LangChain, RAG, 실습 주제의 원본 강의 자료 |
# | 정리 문서 | `Book/05.LLM 기본_20260701_정리.md` | PDF 내용을 페이지별로 정리한 중간 산출물 |
# | 실습 노트북 1 | `LLM/llm.ipynb` | Hugging Face, LangChain, Gradio, RAG, 벡터스토어 중심 실습 |
# | 실습 노트북 2 | `LLM/llm2.ipynb` | DB 접속 챗봇, LangGraph, LangSmith, 응용 실습 중심 노트북 |
#
# 새 교재는 위 세 가지 핵심 자료인 PDF, `llm.ipynb`, `llm2.ipynb`를 기준으로 내용을 확장하고 재구성했습니다.

# %% [markdown]
# ## C.2 PDF 교재 내용 대응표
#
# | PDF의 주요 내용 | 새 교재 반영 위치 | 설명 |
# |---|---|---|
# | LLM과 NLP 기본 개념 | 01장 | LLM, NLP, 생성형 AI, 언어모델의 기본 개념으로 정리 |
# | Transformer 구조 | 02장 | Attention, Encoder, Decoder, Self-Attention 개념으로 확장 |
# | Hugging Face와 Transformer Pipeline | 03장 | Pipeline 사용법과 텍스트 처리 실습으로 구성 |
# | 국내외 LLM과 로컬 LLM | 04장 | OpenAI, Gemini, Claude, Ollama, 로컬 모델 실행 개념으로 정리 |
# | LangChain 기본 | 05장 | Prompt, LLM, Parser, Chain, Runnable 개념으로 정리 |
# | Gradio 챗봇 | 06장 | Gradio 기반 LLM 챗봇 UI 구성으로 확장 |
# | RAG 개념 | 07장 | Retrieval-Augmented Generation 흐름과 구성 요소로 정리 |
# | FAISS 실습 | 08장 | FAISS 기반 벡터 검색과 RAG 실습으로 반영 |
# | Chroma 실습 | 09장 | Chroma 벡터스토어 구성과 RAG 실습으로 반영 |
# | 웹 URL 기반 RAG | 10장 | 웹 문서 로드, 요약, URL 기반 RAG 흐름으로 정리 |
# | 벡터스토어와 DB 비교 | 11장 | 정형 데이터와 비정형 문서 검색 차이로 정리 |
# | DB 접속 LLM 챗봇 | 12장 | 자연어 질문, SQL 생성, SQL 검증, DB 실행, 답변 생성으로 확장 |
# | LangGraph | 13장 | State, Node, Edge, 조건 분기 그래프 실습으로 정리 |
# | LangSmith | 14장 | Trace, Run, Dataset, 평가와 디버깅 흐름으로 정리 |
# | STT/TTS | 15장 | 음성 입력과 음성 출력 보조 실습으로 정리 |
# | 이미지 분류와 멀티모달 | 16장 | Hugging Face 이미지 분류와 LLM 설명 연결로 정리 |
# | 워드클라우드 | 17장 | 텍스트 전처리, 빈도 분석, 워드클라우드 생성으로 정리 |
# | 자기소개서 도우미 | 18장 | 문서 피드백 챗봇 응용 실습으로 확장 |
# | 파인튜닝, 지식증류, RAG 비교 | 19장 | LLM 맞춤화 전략 비교로 정리 |
# | 다중 에이전트와 AutoGen | 20장 | 역할 기반 에이전트 협업 구조로 정리 |
# | 전체 프로젝트 정리 | 21장 | 전체 학습 흐름과 최종 프로젝트 체크리스트로 정리 |

# %% [markdown]
# ## C.3 `llm.ipynb` 내용 대응표
#
# | `llm.ipynb`의 주요 실습 | 새 교재 반영 위치 | 반영 방식 |
# |---|---|---|
# | Hugging Face Pipeline | 03장 | Pipeline 개념, 설치, 기본 사용법, 결과 해석으로 확장 |
# | 텍스트 분류, 요약, 번역 등 Transformer 작업 | 03장 | 작업별 Pipeline 사용 방식으로 정리 |
# | 로컬 LLM 또는 외부 LLM 호출 개념 | 04장 | 국내외 LLM과 Ollama 실행 구조로 정리 |
# | LangChain 기본 Chain | 05장 | PromptTemplate, LLM, OutputParser 연결로 정리 |
# | ChatPromptTemplate 사용 | 05장 | 채팅형 프롬프트 구성 방식으로 반영 |
# | StrOutputParser 사용 | 05장 | 모델 응답을 문자열로 변환하는 파서로 설명 |
# | Gradio 챗봇 만들기 | 06장 | Blocks, ChatInterface, Textbox, Button UI로 확장 |
# | RAG 기본 구조 | 07장 | Loader, Splitter, Embedding, VectorStore, Retriever 흐름으로 재구성 |
# | 문서 로드와 텍스트 분할 | 07장, 08장, 09장 | PDF, 텍스트, 웹 문서 처리 흐름에 반영 |
# | FAISS 벡터스토어 | 08장 | FAISS 기반 RAG 실습으로 상세화 |
# | Chroma 벡터스토어 | 09장 | Chroma 저장, 검색, retriever 구성으로 상세화 |
# | 웹 URL 문서 처리 | 10장 | WebBaseLoader, 웹 문서 요약, URL 기반 RAG로 정리 |
# | 벡터스토어와 일반 DB의 차이 | 11장 | 검색 방식, 데이터 형태, 사용 사례 비교로 정리 |
# | Gradio와 RAG 연결 | 08장, 09장, 10장 | 사용자가 질문하면 검색 후 LLM 답변을 반환하는 UI 구조로 반영 |

# %% [markdown]
# ## C.4 `llm2.ipynb` 내용 대응표
#
# | `llm2.ipynb`의 주요 실습 | 새 교재 반영 위치 | 반영 방식 |
# |---|---|---|
# | DB 접속 챗봇 예제 | 12장 | SQLAlchemy 연결, SQL 생성, SQL 실행, 자연어 답변 생성으로 확장 |
# | MySQL 또는 DB 연결 준비 | 12장, Appendix A | DB_URL, create_engine, DB 드라이버 설치로 정리 |
# | 자연어 질문을 SQL로 변환 | 12장 | SQL 생성 프롬프트와 `EnhancedQueryGenerator` 구조로 반영 |
# | SQL 추출 정규표현식 | 12장 | LLM 응답에서 SQL만 추출하는 함수로 정리 |
# | DB 스키마 확인 | 12장 | 테이블과 컬럼 정보를 읽어 LLM에 전달하는 흐름으로 정리 |
# | SQL 실행 결과를 답변으로 변환 | 12장 | DataFrame 결과를 자연어로 설명하는 프롬프트로 반영 |
# | SQL 안전성 주의 | 12장, Appendix B | SELECT 중심 검증 함수와 위험 키워드 차단으로 확장 |
# | LangGraph 개념 | 13장 | State, Node, Edge, 조건 분기로 재구성 |
# | DB 흐름의 그래프화 | 13장 | read_schema, generate_sql, validate_sql, execute_sql 노드로 반영 |
# | LangSmith 추적 | 14장 | Trace, Run, RAG/DB/LangGraph 추적 예시로 정리 |
# | STT/TTS 보조 실습 | 15장 | Whisper, gTTS, Gradio 음성 챗봇으로 확장 |
# | 이미지 분류 실습 | 16장 | Hugging Face image-classification pipeline과 Gradio UI로 정리 |
# | 워드클라우드 실습 | 17장 | 단어 빈도, WordCloud, KoNLPy, Gradio 시각화 UI로 정리 |
# | 자기소개서 도우미 | 18장 | 피드백, 개선 문장, 면접 질문 생성 챗봇으로 정리 |
# | 파인튜닝, 지식증류, RAG 비교 | 19장 | 전략 비교와 의사결정 도우미로 정리 |
# | AutoGen 또는 다중 에이전트 | 20장 | Planner, Writer, Reviewer, Finalizer 역할 구조로 정리 |

# %% [markdown]
# ## C.5 새 교재 파일별 원본 반영 요약
#
# | 새 교재 파일 | 주요 원본 | 설명 |
# |---|---|---|
# | `00_실습_환경_준비.ipynb` | PDF, 노트북 공통 | VS Code, Jupyter, Python 환경 준비 |
# | `01_LLM과_NLP_기본_개념.ipynb` | PDF | LLM과 NLP 이론 기초 |
# | `02_Transformer_구조_이해.ipynb` | PDF | Transformer 구조와 Attention 설명 |
# | `03_Hugging_Face와_Transformer_Pipeline.ipynb` | PDF, `llm.ipynb` | Hugging Face Pipeline 실습 |
# | `04_국내외_LLM과_로컬_LLM_실행.ipynb` | PDF, `llm.ipynb` | LLM 종류와 로컬 모델 실행 |
# | `05_LangChain_기본.ipynb` | PDF, `llm.ipynb` | LangChain 기본 구성 요소 |
# | `06_Gradio_기반_LLM_챗봇_만들기.ipynb` | PDF, `llm.ipynb` | Gradio 챗봇 UI |
# | `07_RAG_검색증강생성_기본.ipynb` | PDF, `llm.ipynb` | RAG 기본 개념 |
# | `08_FAISS_기반_RAG_실습.ipynb` | PDF, `llm.ipynb` | FAISS RAG 실습 |
# | `09_Chroma_기반_RAG_실습.ipynb` | PDF, `llm.ipynb` | Chroma RAG 실습 |
# | `10_웹_URL_기반_RAG와_웹_문서_요약.ipynb` | PDF, `llm.ipynb` | 웹 문서 기반 RAG와 요약 |
# | `11_벡터스토어와_데이터베이스_비교.ipynb` | PDF, `llm.ipynb`, `llm2.ipynb` | 벡터 검색과 DB 질의 비교 |
# | `12_DB_접속_LLM_챗봇.ipynb` | PDF, `llm2.ipynb` | DB 접속 챗봇 핵심 실습 |
# | `13_LangGraph.ipynb` | PDF, `llm2.ipynb` | 그래프 기반 LLM 실행 흐름 |
# | `14_LangSmith.ipynb` | PDF, `llm2.ipynb` | 추적, 평가, 디버깅 |
# | `15_STT와_TTS_보조_실습.ipynb` | PDF, `llm2.ipynb` | 음성 입출력 확장 |
# | `16_이미지_분류와_멀티모달_실습.ipynb` | PDF, `llm2.ipynb` | 이미지 입력과 멀티모달 확장 |
# | `17_워드클라우드와_텍스트_시각화.ipynb` | PDF, `llm2.ipynb` | 텍스트 시각화와 분석 |
# | `18_자기소개서_도우미_챗봇.ipynb` | PDF, `llm2.ipynb` | LLM 문서 피드백 응용 |
# | `19_파인튜닝_지식증류_RAG_비교.ipynb` | PDF, `llm2.ipynb` | LLM 활용 전략 비교 |
# | `20_다중_에이전트와_AutoGen.ipynb` | PDF, `llm2.ipynb` | 다중 에이전트 구조 |
# | `21_전체_실습_프로젝트_정리.ipynb` | 전체 원본 | 전체 프로젝트 흐름 정리 |
# | `Appendix_A_설치_명령어_모음.ipynb` | 전체 원본 | 설치 명령어 통합 정리 |
# | `Appendix_B_주요_오류와_해결_방법.ipynb` | 전체 원본 | 오류 해결 방법 통합 정리 |
# | `Appendix_C_원본_자료_대응표.ipynb` | 전체 원본 | 원본과 새 교재의 대응 관계 정리 |

# %% [markdown]
# ## C.6 주제별 반영 위치 빠른 찾기
#
# | 찾고 싶은 주제 | 확인할 장 |
# |---|---|
# | LLM이 무엇인지 | 01장 |
# | Transformer와 Attention | 02장 |
# | Hugging Face Pipeline | 03장 |
# | Ollama와 로컬 LLM | 04장 |
# | LangChain Prompt, Chain, Parser | 05장 |
# | Gradio 챗봇 | 06장 |
# | RAG 기본 | 07장 |
# | FAISS | 08장 |
# | Chroma | 09장 |
# | 웹 문서 요약 | 10장 |
# | 벡터스토어와 DB 차이 | 11장 |
# | DB 접속 챗봇 | 12장 |
# | LangGraph | 13장 |
# | LangSmith | 14장 |
# | STT/TTS | 15장 |
# | 이미지 분류 | 16장 |
# | 워드클라우드 | 17장 |
# | 자기소개서 챗봇 | 18장 |
# | 파인튜닝, 지식증류, RAG 비교 | 19장 |
# | AutoGen과 다중 에이전트 | 20장 |
# | 전체 프로젝트 정리 | 21장 |
# | 설치 명령어 | Appendix A |
# | 오류 해결 | Appendix B |
# | 원본 대응표 | Appendix C |

# %%
# 교재 위치: Appendix C - 원본 대응표를 데이터로 정리
# 이 셀은 원본 자료와 새 교재 장의 대응 관계를 pandas DataFrame으로 정리합니다.

# pandas는 표 형태의 데이터를 만들고 확인할 때 사용합니다.
import pandas as pd

# mapping_data 변수에는 주제별 원본과 새 교재 반영 위치를 저장합니다.
mapping_data = [
    # LLM 기본 개념 대응 정보입니다.
    {"topic": "LLM/NLP 기본", "source": "PDF", "chapter": "01장"},
    # Transformer 구조 대응 정보입니다.
    {"topic": "Transformer", "source": "PDF", "chapter": "02장"},
    # Hugging Face 대응 정보입니다.
    {"topic": "Hugging Face Pipeline", "source": "PDF, llm.ipynb", "chapter": "03장"},
    # LangChain 대응 정보입니다.
    {"topic": "LangChain", "source": "PDF, llm.ipynb", "chapter": "05장"},
    # Gradio 대응 정보입니다.
    {"topic": "Gradio 챗봇", "source": "PDF, llm.ipynb", "chapter": "06장"},
    # RAG 대응 정보입니다.
    {"topic": "RAG", "source": "PDF, llm.ipynb", "chapter": "07~10장"},
    # DB 챗봇 대응 정보입니다.
    {"topic": "DB 접속 챗봇", "source": "PDF, llm2.ipynb", "chapter": "12장"},
    # LangGraph 대응 정보입니다.
    {"topic": "LangGraph", "source": "PDF, llm2.ipynb", "chapter": "13장"},
    # LangSmith 대응 정보입니다.
    {"topic": "LangSmith", "source": "PDF, llm2.ipynb", "chapter": "14장"},
    # 응용 실습 대응 정보입니다.
    {"topic": "응용 실습", "source": "PDF, llm2.ipynb", "chapter": "15~20장"},
]

# mapping_df는 대응 정보를 표 형태로 저장한 DataFrame입니다.
mapping_df = pd.DataFrame(mapping_data)

# 대응표를 출력합니다.
mapping_df

# %% [markdown]
# ## C.7 누락 방지 점검 기준
#
# 원본 자료를 새 교재로 재구성할 때 다음 기준으로 누락을 방지했습니다.
#
# 1. PDF의 주요 장과 슬라이드 주제를 새 교재의 장으로 분리했습니다.
# 2. `llm.ipynb`의 텍스트 모델, LangChain, Gradio, RAG 실습을 03~11장에 반영했습니다.
# 3. `llm2.ipynb`의 DB 챗봇과 고급 응용 실습을 12~20장에 반영했습니다.
# 4. 각 실습 코드는 한 줄 단위로 주석을 추가하는 방식으로 작성했습니다.
# 5. 각 장의 마지막에는 핵심 정리와 다음 장 연결 설명을 넣었습니다.
# 6. 설치와 오류 해결은 본문에서 반복되는 내용을 부록으로 통합했습니다.
# 7. 전체 흐름은 21장에서 프로젝트 관점으로 다시 정리했습니다.
#
# 이 대응표를 사용하면 특정 원본 내용을 새 교재에서 어디로 찾아가야 하는지 빠르게 확인할 수 있습니다.

# %% [markdown]
# ## C.8 정리
#
# 이 부록에서는 원본 PDF, `llm.ipynb`, `llm2.ipynb`와 새 교재 장들의 대응 관계를 정리했습니다.
#
# 핵심 정리는 다음과 같습니다.
#
# - PDF의 이론과 전체 주제는 01~21장 전체 구조의 기준이 되었습니다.
# - `llm.ipynb`의 주요 실습은 Hugging Face, LangChain, Gradio, RAG 관련 장에 반영되었습니다.
# - `llm2.ipynb`의 주요 실습은 DB 챗봇, LangGraph, LangSmith, 응용 실습 장에 반영되었습니다.
# - 설치 명령어는 Appendix A에 통합했습니다.
# - 오류 해결 방법은 Appendix B에 통합했습니다.
# - 전체 새 교재의 출처 추적과 누락 방지 점검은 Appendix C에서 확인할 수 있습니다.
#
# 다음 단계에서는 전체 목차 파일을 별도로 만들어, 모든 장과 부록을 한눈에 볼 수 있도록 정리합니다.
